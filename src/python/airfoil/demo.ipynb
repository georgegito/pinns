# %%
import os
from dotenv import load_dotenv
import sys

# %%
load_dotenv()
lib_dir = os.environ.get("LOCAL_LIB_DIR")
sys.path.append(lib_dir)

# %%
import numpy as np
import matplotlib.pyplot as plt
import naca4digit_airfoil as naca4digit_airfoil

# %%
# Define airfoil parameters (example: NACA 2412)
chord = 1.0
m = 0.02  # maximum camber
p = 0.4   # position of maximum camber
t = 0.12  # maximum thickness
alpha_deg = 10.0 # angle of attack in degrees
num_points = 1000

airfoil = naca4digit_airfoil.Naca4DigitAirfoil(chord, m, p, t, num_points=num_points, alpha_deg=alpha_deg)

fig, ax = plt.subplots(figsize=(12, 7))
airfoil.plot(ax=ax)
ax.set_xlim(-0.5, 1.5)
ax.set_ylim(-1.5, 1.5)
plt.show()

# %%
x_in, y_in = airfoil.generate_interior_points()

# %%
# Plotting
fig, ax = plt.subplots(figsize=(12, 7))
airfoil.plot(ax=ax)
ax.scatter(x_in, y_in, s=1, label='Interior Points')
ax.set_title('Interior Points within NACA 4-Digit Airfoil')
ax.set_xlim(-0.5, 1.5)
ax.set_ylim(-1.5, 1.5)
ax.legend()
plt.show()

# %%
x_sampled, y_sampled = airfoil.sample_surface_points(30)

# Plotting
fig, ax = plt.subplots(figsize=(12, 7))
airfoil.plot(ax=ax)
ax.scatter(x_sampled, y_sampled, s=5, label='Sampled Surface Points', c='r')
ax.set_title('Sampled Surface Points within NACA 4-Digit Airfoil')
ax.set_xlim(-0.5, 1.5)
ax.set_ylim(-1.5, 1.5)
ax.legend()
plt.show()

# %%
# Sample points for classification
x_values = np.random.uniform(low=-.5, high=1.5, size=1000)
y_values = np.random.uniform(low=-1.5, high=1.5, size=1000)

interior_points, exterior_points = airfoil.classify_points(np.column_stack((x_values, y_values)))

# %%
fig, ax = plt.subplots(figsize=(12, 7))
airfoil.plot(ax=ax)
if len(exterior_points) > 0:
    ax.scatter(exterior_points[:, 0], exterior_points[:, 1], s=1, color='green', label='Exterior Points')
if len(interior_points) > 0:
    ax.scatter(interior_points[:, 0], interior_points[:, 1], s=1, color='purple', label='Interior Points')
ax.set_title('Classified Points Relative to an Airfoil')
ax.set_xlim(-0.5, 1.5)
ax.set_ylim(-1.5, 1.5)
plt.show()

# %%
x_sampled, y_sampled = airfoil.sample_points_in_domain_around(1000, 0.2*airfoil.chord)
_, exterior_points = airfoil.classify_points(np.column_stack((x_sampled, y_sampled)))
x_sampled = exterior_points[:, 0]
y_sampled = exterior_points[:, 1]

# Plotting
fig, ax = plt.subplots(figsize=(12, 7))
airfoil.plot(ax=ax)
ax.scatter(x_sampled, y_sampled, s=5, label='Sampled Points', c='r')
ax.set_title('Sampled Points Around NACA 4-Digit Airfoil')
ax.set_xlim(-0.5, 1.5)
ax.set_ylim(-1.5, 1.5)
ax.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 x_sampled, y_sampled = airfoil.sample_points_in_domain_around(1000, 0.2*airfoil.chord)
#       2 _, exterior_points = airfoil.classify_points(np.column_stack((x_sampled, y_sampled)))
#       3 x_sampled = exterior_points[:, 0]
#
# File ~/repos/pinns/src/python/lib/naca4digit_airfoil.py:200, in Naca4DigitAirfoil.sample_points_in_domain_around(self, num_points, distance)
#     189 def sample_points_in_domain_around(self, num_points: int, distance: float) -> tuple:
#     190   """
#     191   Sample points in the domain around the airfoil.
#     192
#    (...)
#     198   - x, y: Coordinates of the points in the domain around the airfoil.
#     199   """
# --> 200   return utils.qmc_sample_points_in_domain_2d(self.x_min - distance, self.x_max + distance, self.y_min - distance, self.y_max + distance, num_points)
#
# TypeError: qmc_sample_points_in_domain_2d() takes 2 positional arguments but 5 were given

# %%
x_sampled, y_sampled = airfoil.sample_points_in_domain_around_leading_edge(1000, 0.2*airfoil.chord)
_, exterior_points = airfoil.classify_points(np.column_stack((x_sampled, y_sampled)))
x_sampled = exterior_points[:, 0]
y_sampled = exterior_points[:, 1]

# Plotting
fig, ax = plt.subplots(figsize=(12, 7))
airfoil.plot(ax=ax)
ax.scatter(x_sampled, y_sampled, s=5, label='Sampled Points', c='r')
ax.set_title('Sampled Points Around NACA 4-Digit Airfoil Leading Edge')
ax.set_xlim(-0.5, 1.5)
ax.set_ylim(-1.5, 1.5)
ax.legend()
plt.show()
