# %% [markdown]
# # Unsteady Heat Conduction Equation

# %% [markdown]
# $$\frac{\partial T(x,t)}{\partial t} = \alpha \frac{\partial^2 T(x,t)}{\partial x^2}$$

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
from torch.optim import LBFGS

# %%
# Problem parameters
L = 1.0  # Length of the domain
alpha = 1.0  # Thermal diffusivity

# Discretization parameters
Nx = 50  # Number of spatial grid points
Nt = 50  # Number of time steps
dx = L / (Nx - 1)
max_time = 0.2  # Maximum time
dt = max_time / (Nt - 1)

# Initial condition
def T_initial(x):
    return np.sin(np.pi * x) + 0.5 * np.sin(3 * np.pi * x) + 0.25 * np.sin(5 * np.pi * x)

# Boundary conditions (Dirichlet)
T_left = 0.0
T_right = 0.0

# %%
# Generate a grid of points in the x-t domain
x_test = np.linspace(0, 1, Nx)
t_test = np.linspace(0, max_time, Nt)
x_grid, t_grid = np.meshgrid(x_test, t_test)

# %%
def plot_initial_temperature():
    # Evaluate the initial condition at the grid points
    T_values = T_initial(x_test)

    # Plot the initial temperature distribution
    plt.figure()
    plt.plot(x_test, T_values, label="Initial Temperature")
    plt.xlabel("x")
    plt.ylabel("Temperature")
    plt.title("Initial Temperature Distribution (t=0)")
    plt.legend()
    plt.show()

# %% [markdown]
# ## PINN

# %%
class PINN(nn.Module):
    def __init__(self, input_dim, output_dim, hidden_units):
        super(PINN, self).__init__()
        self.layers = nn.ModuleList()
        in_units = input_dim
        for units in hidden_units:
            self.layers.append(nn.Linear(in_units, units))
            in_units = units
        self.layers.append(nn.Linear(in_units, output_dim))

    def forward(self, x):
        for layer in self.layers[:-1]:
            x = torch.sigmoid(layer(x))
        x = self.layers[-1](x)
        return x

    def loss(self, x_f, t_f, alpha, T_left, T_right, T_initial):
        T = self(torch.cat([x_f, t_f], dim=1))

        T_x = torch.autograd.grad(T, x_f, grad_outputs=torch.ones_like(T), create_graph=True, retain_graph=True, only_inputs=True)[0]
        T_xx = torch.autograd.grad(T_x, x_f, grad_outputs=torch.ones_like(T_x), create_graph=True, retain_graph=True, only_inputs=True)[0]
        T_t = torch.autograd.grad(T, t_f, grad_outputs=torch.ones_like(T), create_graph=True, retain_graph=True, only_inputs=True)[0]

        f = T_t - alpha * T_xx # physics residual

        # Initial condition loss
        T_initial_pred = self(torch.cat([x_f, torch.zeros_like(t_f)], dim=1))
        T_initial_true = T_initial(x_f.detach().numpy())  # Detach x before converting to a numpy array
        T_initial_true = torch.tensor(T_initial_true, dtype=torch.float32)  # Convert back to a tensor
        ic_loss = torch.mean(torch.square(T_initial_pred - T_initial_true))

        # Boundary conditions loss
        T_left_pred = self(torch.cat([torch.zeros_like(x_f), t_f], dim=1))
        T_right_pred = self(torch.cat([torch.ones_like(x_f), t_f], dim=1))
        bc_loss = torch.mean(torch.square(T_left_pred - T_left)) + torch.mean(torch.square(T_right_pred - T_right))

        # Combine PDE residual, initial condition, and boundary condition losses
        total_loss = torch.mean(torch.square(f)) + ic_loss + bc_loss

        return total_loss

# %%
def pinn_demo_lbfgs(epochs=1000, learning_rate=0.01, existing_pinn=None):
    # device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    device = "cpu"
  
    if not existing_pinn:
        input_dim = 2
        output_dim = 1
        hidden_units = [16, 16]
        pinn = PINN(input_dim, output_dim, hidden_units).to(device)
    else:
        pinn = existing_pinn

    alpha = 1.0
    Nf = Nx * Nt # number of collocation points - batch size
    optimizer = torch.optim.LBFGS(pinn.parameters(), lr=learning_rate, max_iter=20)

    def closure():
        optimizer.zero_grad()
        x_f = torch.tensor(np.random.uniform(0, 1, size=(Nf, 1)), dtype=torch.float32, device=device, requires_grad=True) # collocation points
        t_f = torch.tensor(np.random.uniform(0, 1, size=(Nf, 1)), dtype=torch.float32, device=device, requires_grad=True) # collocation points
        loss = pinn.loss(x_f, t_f, alpha, T_left, T_right, T_initial)
        loss.backward()
        return loss

    for epoch in range(epochs):
        optimizer.step(closure)
        if epoch % 100 == 0:
            loss = closure()
            print(f'Epoch: {epoch}, Loss: {loss.item()}')

    # Evaluate the model at the grid points
    x_test_tensor = torch.tensor(x_grid.reshape(-1, 1), dtype=torch.float32, device=device, requires_grad=True)
    t_test_tensor = torch.tensor(t_grid.reshape(-1, 1), dtype=torch.float32, device=device, requires_grad=True)
    T_test = pinn(torch.cat([x_test_tensor, t_test_tensor], dim=1))
    T_test = T_test.detach().cpu().numpy().reshape(Nt, Nx) # maybe reversed

    # Create a contour plot of the temperature distribution
    plt.figure()
    plt.contourf(x_test, t_test, T_test, cmap="jet")
    plt.xlabel("x")
    plt.ylabel("t")
    plt.title("Temperature Distribution (PINN)")
    plt.colorbar(label="Temperature")
    plt.show()

    return T_test, pinn

# %%
def pinn_demo_adam(epochs=10000, learning_rate=1e-3, existing_pinn=None):
    # device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    device = "cpu"
  
    if not existing_pinn:
        input_dim = 2
        output_dim = 1
        hidden_units = [16, 16]
        pinn = PINN(input_dim, output_dim, hidden_units).to(device)
    else:
        pinn = existing_pinn

    alpha = 1.0
    Nf = Nx * Nt # number of collocation points - batch size
    optimizer = torch.optim.Adam(pinn.parameters(), lr=learning_rate)

    for epoch in range(epochs):
        x_f = torch.tensor(np.random.uniform(0, 1, size=(Nf, 1)), dtype=torch.float32, device=device, requires_grad=True) # collocation points
        t_f = torch.tensor(np.random.uniform(0, 1, size=(Nf, 1)), dtype=torch.float32, device=device, requires_grad=True) # collocation points
        
        optimizer.zero_grad()
        loss = pinn.loss(x_f, t_f, alpha, T_left, T_right, T_initial)
        loss.backward()
        optimizer.step()

        if epoch % 1000 == 0:
            print(f'Epoch: {epoch}, Loss: {loss.item()}')

    # Evaluate the model at the grid points
    x_test_tensor = torch.tensor(x_grid.reshape(-1, 1), dtype=torch.float32, device=device, requires_grad=True)
    t_test_tensor = torch.tensor(t_grid.reshape(-1, 1), dtype=torch.float32, device=device, requires_grad=True)
    T_test = pinn(torch.cat([x_test_tensor, t_test_tensor], dim=1))
    T_test = T_test.detach().cpu().numpy().reshape(Nt, Nx) # maybe reversed

    # Create a contour plot of the temperature distribution
    plt.figure()
    plt.contourf(x_test, t_test, T_test, cmap="jet")
    plt.xlabel("x")
    plt.ylabel("t")
    plt.title("Temperature Distribution (PINN)")
    plt.colorbar(label="Temperature")
    plt.show()

    return T_test, pinn

# %%
def analytical_solution(alpha):
    term1 = np.sin(np.pi * x_grid) * np.exp(-(np.pi * alpha)**2 * t_grid)
    term2 = 0.5 * np.sin(3 * np.pi * x_grid) * np.exp(-(9 * np.pi * alpha)**2 * t_grid)
    term3 = 0.25 * np.sin(5 * np.pi * x_grid) * np.exp(-(25 * np.pi * alpha)**2 * t_grid)

    T = term1 + term2 + term3
    return T

def compute_analytical_solution():
    T_analytical = analytical_solution(x_test, t_test, alpha)

    plt.figure()
    plt.contourf(x_test, t_test, T_analytical, cmap="jet")
    plt.xlabel("x")
    plt.ylabel("t")
    plt.title("Temperature Distribution (Analytical)")
    plt.colorbar(label="Temperature")
    plt.show()

    return T_analytical

# %%
plot_initial_temperature()

# %%
pinn_solution, pinn = pinn_demo_adam()
# Out:
# Epoch: 0, Loss: 2.0837507247924805
# Epoch: 10, Loss: 1.5389127731323242
# Epoch: 20, Loss: 1.1157945394515991
# Epoch: 30, Loss: 0.813761830329895
# Epoch: 40, Loss: 0.6359652280807495
# Epoch: 50, Loss: 0.527782678604126
# Epoch: 60, Loss: 0.4802830219268799
# Epoch: 70, Loss: 0.4596989154815674
# Epoch: 80, Loss: 0.4476393163204193
# Epoch: 90, Loss: 0.4442727267742157
# Epoch: 100, Loss: 0.451520711183548
# Epoch: 110, Loss: 0.44956889748573303
# Epoch: 120, Loss: 0.4472443461418152
# Epoch: 130, Loss: 0.44002264738082886
# Epoch: 140, Loss: 0.4409932792186737
# Epoch: 150, Loss: 0.44308537244796753
# Epoch: 160, Loss: 0.44381558895111084
# Epoch: 170, Loss: 0.4351041316986084
# Epoch: 180, Loss: 0.442482590675354
# Epoch: 190, Loss: 0.4354434609413147
# Epoch: 200, Loss: 0.43032217025756836
# Epoch: 210, Loss: 0.43688979744911194
# Epoch: 220, Loss: 0.43802231550216675
# Epoch: 230, Loss: 0.43716615438461304
# Epoch: 240, Loss: 0.43331336975097656
# Epoch: 250, Loss: 0.43414196372032166
# Epoch: 260, Loss: 0.43177875876426697
# Epoch: 270, Loss: 0.42912065982818604
# Epoch: 280, Loss: 0.4304462671279907
# Epoch: 290, Loss: 0.4250051975250244
# Epoch: 300, Loss: 0.42271241545677185
# Epoch: 310, Loss: 0.43052518367767334
# Epoch: 320, Loss: 0.4300318956375122
# Epoch: 330, Loss: 0.42678534984588623
# Epoch: 340, Loss: 0.4283314347267151
# Epoch: 350, Loss: 0.4270137548446655
# Epoch: 360, Loss: 0.42341524362564087
# Epoch: 370, Loss: 0.4230893850326538
# Epoch: 380, Loss: 0.4190309941768646
# Epoch: 1630, Loss: 0.32335007190704346
# Epoch: 1640, Loss: 0.3207300901412964
# Epoch: 1650, Loss: 0.322755366563797
# Epoch: 1660, Loss: 0.3267161548137665
# Epoch: 1670, Loss: 0.3164117932319641
# Epoch: 1680, Loss: 0.3225172460079193
# Epoch: 1690, Loss: 0.3173845708370209
# Epoch: 1700, Loss: 0.3111623227596283
# Epoch: 1710, Loss: 0.30736398696899414
# Epoch: 1720, Loss: 0.3222711980342865
# Epoch: 1730, Loss: 0.31346240639686584
# Epoch: 1740, Loss: 0.302937388420105
# Epoch: 1750, Loss: 0.3053181767463684
# Epoch: 1760, Loss: 0.30192485451698303
# Epoch: 1770, Loss: 0.2964383065700531
# Epoch: 1780, Loss: 0.29708486795425415
# Epoch: 1790, Loss: 0.29906871914863586
# Epoch: 1800, Loss: 0.2890334129333496
# Epoch: 1810, Loss: 0.29808562994003296
# Epoch: 1820, Loss: 0.2914998531341553
# Epoch: 1830, Loss: 0.2910936176776886
# Epoch: 1840, Loss: 0.28466561436653137
# Epoch: 1850, Loss: 0.2805061936378479
# Epoch: 1860, Loss: 0.2860180139541626
# Epoch: 1870, Loss: 0.2755637764930725
# Epoch: 1880, Loss: 0.28774264454841614
# Epoch: 1890, Loss: 0.28005367517471313
# Epoch: 1900, Loss: 0.28695088624954224
# Epoch: 1910, Loss: 0.2863749861717224
# Epoch: 1920, Loss: 0.27139925956726074
# Epoch: 1930, Loss: 0.28332066535949707
# Epoch: 1940, Loss: 0.27128368616104126
# Epoch: 1950, Loss: 0.27437567710876465
# Epoch: 1960, Loss: 0.27247387170791626
# Epoch: 1970, Loss: 0.2773892879486084
# Epoch: 1980, Loss: 0.2821424901485443
# Epoch: 1990, Loss: 0.27677711844444275

# %%
pinn_solution, pinn = pinn_demo_lbfgs()
# Out:
# Epoch: 0, Loss: 0.4525797963142395
# Epoch: 10, Loss: 0.20750996470451355
# Epoch: 20, Loss: nan
# Epoch: 30, Loss: nan
# Epoch: 40, Loss: nan
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 pinn_solution, pinn = pinn_demo_lbfgs(epochs=1000, learning_rate=0.1)
#
# Cell In[5], line 68, in pinn_demo_lbfgs(epochs, learning_rate, existing_pinn)
#      65     return loss
#      67 for epoch in range(epochs):
# ---> 68     optimizer.step(closure)
#      69     if epoch % 10 == 0:
#      70         loss = closure()
#
# File c:\Users\gitop\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\optim\optimizer.py:280, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     276         else:
#     277             raise RuntimeError(f"{func} must return None or a tuple of (new_args, new_kwargs),"
#     278                                f"but got {result}.")
# --> 280 out = func(*args, **kwargs)
#     281 self._optimizer_step_code()
#     283 # call optimizer step post hooks
#
# File c:\Users\gitop\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File c:\Users\gitop\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\optim\lbfgs.py:383, in LBFGS.step(self, closure)
#     381 for i in range(num_old - 1, -1, -1):
#     382     al[i] = old_stps[i].dot(q) * ro[i]
# --> 383     q.add_(old_dirs[i], alpha=-al[i])
#     385 # multiply by initial Hessian
#     386 # r/d is the final direction
#     387 d = r = torch.mul(q, H_diag)
#
# KeyboardInterrupt:

# %%
solution = compute_analytical_solution()

# %%
mse_pinn = np.mean((pinn_solution - solution)**2)
print(f"MSE PINN: {mse_pinn}")
# Out:
# MSE PINN: 0.012990808698875611
